# %%
'''Part 02 : Neural Networks
# Module 01: Neural Networks
# Lesson 07: Keras
# Multi-layer feedforward neural network to solve the XOR problem
# '''
# Out:
# 'Part 02 : Neural Networks\n# Module 01: Neural Networks\n# Lesson 07: Keras\n# Multi-layer feedforward neural network to solve the XOR problem\n# '

# %%
import numpy as np
from keras.utils import np_utils
import tensorflow as tf
# Using TensorFlow 1.0.0; use tf.python_io in later versions
# tf.python.control_flow_ops = tf
tf.python_io = tf

# Set random seed
np.random.seed(42)

# Our data
X = np.array([[0,0],[0,1],[1,0],[1,1]]).astype('float32')
y = np.array([[0],[1],[1],[0]]).astype('float32')

# Initial Setup for Keras
from keras.models import Sequential
from keras.layers.core import Dense, Activation
# One-hot encoding the output
y = np_utils.to_categorical(y)

# Building the model
xor = Sequential()

# Add required layers
# xor.add()

xor.add(Dense(8, input_dim= x.shape[1]))
xor.add(Activation('relu'))
xor.add(Dense(2))
xor.add(Activation('softmax'))

# Specify loss as "binary_crossentropy", optimizer as "adam",
# and add the accuracy metric
# xor.compile()

xor.compile(loss="categorical_crossentropy", optimizer="adam", metrics = ["accuracy"])

# Uncomment this line to print the model architecture
xor.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_15 (Dense)             (None, 8)                 24
# _________________________________________________________________
# activation_15 (Activation)   (None, 8)                 0
# _________________________________________________________________
# dense_16 (Dense)             (None, 2)                 18
# _________________________________________________________________
# activation_16 (Activation)   (None, 2)                 0
# ...
# Total params: 42
# Trainable params: 42
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fitting the model
history = xor.fit(X, y, epochs=150, verbose=1)
# Out:
# Epoch 1/150
# 4/4 [==============================] - 0s 24ms/step - loss: 0.6750 - accuracy: 0.7500
# Epoch 2/150
# 4/4 [==============================] - 0s 748us/step - loss: 0.6737 - accuracy: 0.7500
# Epoch 3/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6724 - accuracy: 0.7500
# Epoch 4/150
# 4/4 [==============================] - 0s 423us/step - loss: 0.6711 - accuracy: 0.7500
# Epoch 5/150
# 4/4 [==============================] - 0s 1ms/step - loss: 0.6698 - accuracy: 0.7500
# Epoch 6/150
# 4/4 [==============================] - 0s 501us/step - loss: 0.6685 - accuracy: 0.7500
# Epoch 7/150
# 4/4 [==============================] - 0s 929us/step - loss: 0.6672 - accuracy: 0.7500
# Epoch 8/150
# 4/4 [==============================] - 0s 633us/step - loss: 0.6660 - accuracy: 0.7500
# Epoch 9/150
# 4/4 [==============================] - 0s 631us/step - loss: 0.6648 - accuracy: 0.7500
# Epoch 10/150
# ...

# %%
# Scoring the model
score = xor.evaluate(X, y)
print("\nAccuracy: ", score[-1])

# Checking the predictions
print("\nPredictions:")
print(xor.predict_proba(X))
# Out:
# 4/4 [==============================] - 0s 18ms/step
#
# Accuracy:  1.0
#
# Predictions:
# [[0.5345593  0.4654407 ]
#  [0.4880081  0.5119919 ]
#  [0.37918875 0.6208113 ]
#  [0.57740223 0.42259783]]
